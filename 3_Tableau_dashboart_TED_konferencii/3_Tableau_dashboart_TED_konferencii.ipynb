# %% [markdown]
# # Проект: Построение дашбордов в Tableau о конференциях TED

# %% [markdown]
# __Описание проекта__
#
# TED (от англ. technology, education, design — «технологии, образование, дизайн») — некоммерческий фонд, который проводит популярные конференции. На них выступают специалисты из разных областей и читают лекции на актуальные социальные, культурные и научные темы.
#
# __Цель проекта:__ Исследовать историю TED-конференций и создать презентацию с дашбордами в Tableau на основе полученных данных.
#
# __Ход исследования:__
#
# 1. Загрузка и изучение данных.
# 2. Построение дашборда "История выступлений", включающий:
#  - визуализацию "Выступления по странам";
#  - визуализацию "Выступления по годам";
#  - визуализацию "Выступления по темам".
# 3. Создание дашборда "Тематики выступлений", включающий:
#  - визуализацию "Выступления по тематикам";
#  - визуализацию "Тематики и страны";
#  - визуализацию "Аплодисменты по тематикам";
#  - визуализацию "Смех по тематикам";
#  - визуализацию "Связь длительности с просмотрами".
# 4. Создание дашборда "Авторы выступлений", включающий:
#  - визуализацию "Области деятельности авторов";
#  - визуализацию "Выступления и число просмотров";
#  - визуализацию "Распределение числа выступлений";
#  - визуализацию "Авторы по числу выступлений".
# 5. Создание дашборда на свободную тему, ответив на вопросы:
#  - Как изменился состав тематик категории "Другие" в 2019-2021 годах?
#  - Можно ли разделить конференции на категории? Как менялась популярность этих категорий со временем.
# 6. Создание презентации.

# %% [markdown]
# Ссылка на презентацию:
#
# https://public.tableau.com/app/profile/polivanova.mariya/viz/TED-_17079539586820/TED

# %% [markdown]
# # Подведение итогов.
#
# В результате работы построены 4 дашборда, объединенные в презентацию, которая отражает исследование истории выступлений TED:
#
# - Отражено количество выступлений по странам, годам и темам.
# - Отражены тематики выступлений в разрезе стран, распределение выступлений по показателям частоты аплодисментов и смеха.
# - Отражены области деятельности авторов, количество их выступлений, а также число просмотров по их выступлениям, распределение максимального числа выступлений приходящегося на автора.
# - Отражены изменения состава тематик категории "Другие" в 2019-2021 годах.
